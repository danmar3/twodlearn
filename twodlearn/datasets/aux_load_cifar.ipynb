# %%
import tarfile
import pickle
import numpy as np

from tensorflow.contrib.learn.python.learn.datasets import base

# %%
local_file= base.maybe_download('cifar-10-python.tar.gz', 'CIFAR10_data', 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz')

# %%
# decompress
with tarfile.open(local_file) as in_file:
    in_file.extractall('CIFAR10_data')

# %%
with open('CIFAR10_data/cifar-10-batches-py/data_batch_1', 'rb') as f:
    data_1 = pickle.load(f, encoding='bytes')

# %%
print(data_1[b'data'].shape)
print(len(data_1[b'labels']))
print(data_1[b'labels'][4])

#print(data_1.keys())
# Out:
# (10000, 3072)
# 10000
# 1

# %%
labels= np.array(data_1[b'labels'])

# %%
print(labels.shape)
# Out:
# (10000,)

# %%
np.max(data_1[b'data'])
# Out:
# 255

# %%
from twodlearn.tf_lib.datasets import CIFAR10 
cifar10 = CIFAR10.read_data_sets("CIFAR10_data/", reshape= False, one_hot=True)
# Out:
# Successfully downloaded cifar-10-python.tar.gz 170498071 bytes.

# %%
batch_x, batch_y = cifar10.train.next_batch(10);

# %%
print(batch_x.shape)
# Out:
# (10, 32, 32, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import clear_output
# %matplotlib inline

# %%
imgplot = plt.imshow(batch_x[5,:,:,:] )

# %%
print(data_1[b'data'].shape)

data_aux = data_1[b'data']
data_aux1= np.reshape(data_aux, [data_aux.shape[0], 3, 32 ,32])
data_aux2 = np.transpose(data_aux1, (0,2,3,1))

print(data_aux2.shape)
imgplot = plt.imshow(data_aux2[9,:,:,:] )
# Out:
# (10000, 3072)
# (10000, 32, 32, 3)
